# %%
import pandas as pd
from IPython.display import display, HTML, clear_output
import ipywidgets as widgets

# Data for NBA Champions, Finals MVP, Regular Season MVP, and their stats (2000-2025)
data = {
    "Year": list(range(2000, 2026)),
    "NBA Champion": [
        "Los Angeles Lakers", "Los Angeles Lakers", "San Antonio Spurs", "Detroit Pistons", "San Antonio Spurs",
        "Miami Heat", "San Antonio Spurs", "Boston Celtics", "Los Angeles Lakers", "Los Angeles Lakers",
        "Dallas Mavericks", "Miami Heat", "Miami Heat", "San Antonio Spurs", "Golden State Warriors",
        "Cleveland Cavaliers", "Golden State Warriors", "Golden State Warriors", "Toronto Raptors", "Los Angeles Lakers",
        "Milwaukee Bucks", "Golden State Warriors", "Denver Nuggets", "Boston Celtics", "Boston Celtics", "TBD"
    ],
    "Beat in Series": [
        "Indiana Pacers (4-2)", "Philadelphia 76ers (4-1)", "New Jersey Nets (4-0)", "Los Angeles Lakers (4-1)", "Detroit Pistons (4-3)",
        "Dallas Mavericks (4-2)", "Cleveland Cavaliers (4-0)", "Los Angeles Lakers (4-2)", "Orlando Magic (4-1)", "Boston Celtics (4-3)",
        "Miami Heat (4-2)", "Oklahoma City Thunder (4-1)", "San Antonio Spurs (4-3)", "Miami Heat (4-1)", "Cleveland Cavaliers (4-1)",
        "Golden State Warriors (4-3)", "Cleveland Cavaliers (4-1)", "Cleveland Cavaliers (4-0)", "Golden State Warriors (4-2)", "Miami Heat (4-2)",
        "Phoenix Suns (4-2)", "Boston Celtics (4-2)", "Miami Heat (4-1)", "Dallas Mavericks (4-1)", "Dallas Mavericks (4-1)", "TBD"
    ],
    "Finals MVP": [
        "Shaquille O'Neal", "Shaquille O'Neal", "Tim Duncan", "Chauncey Billups", "Tim Duncan",
        "Dwyane Wade", "Tony Parker", "Paul Pierce", "Kobe Bryant", "Kobe Bryant",
        "Dirk Nowitzki", "LeBron James", "LeBron James", "Kawhi Leonard", "Andre Iguodala",
        "LeBron James", "Kevin Durant", "Kevin Durant", "Kawhi Leonard", "LeBron James",
        "Giannis Antetokounmpo", "Stephen Curry", "Nikola Jokić", "Jaylen Brown", "Jaylen Brown", "TBD"
    ],
    "Finals MVP Stats (PPG, APG, RPG)": [
        "38.0 ppg, 2.3 apg, 16.7 rpg", "33.0 ppg, 3.8 apg, 15.8 rpg", "24.2 ppg, 5.3 apg, 17.0 rpg",
        "21.0 ppg, 5.2 apg, 5.2 rpg", "20.6 ppg, 2.4 apg, 14.1 rpg", "34.7 ppg, 3.8 apg, 7.8 rpg",
        "24.5 ppg, 5.0 apg, 5.0 rpg", "21.8 ppg, 4.5 apg, 6.3 rpg", "28.6 ppg, 4.2 apg, 8.0 rpg",
        "27.5 ppg, 5.5 apg, 9.1 rpg", "26.0 ppg, 2.0 apg, 9.7 rpg", "28.6 ppg, 10.2 apg, 7.4 rpg",
        "25.3 ppg, 7.0 apg, 10.9 rpg", "17.8 ppg, 2.0 apg, 6.4 rpg", "16.3 ppg, 4.0 apg, 5.8 rpg",
        "29.7 ppg, 8.9 apg, 11.3 rpg", "35.2 ppg, 5.4 apg, 8.2 rpg", "28.8 ppg, 7.5 apg, 10.8 rpg",
        "28.5 ppg, 4.2 apg, 9.8 rpg", "29.8 ppg, 11.8 apg, 8.5 rpg", "35.2 ppg, 5.2 apg, 13.2 rpg",
        "31.2 ppg, 6.0 apg, 5.0 rpg", "30.2 ppg, 6.4 apg, 14.0 rpg", "25.5 ppg, 5.7 apg, 10.5 rpg", 
        "25.5 ppg, 5.7 apg, 10.5 rpg", "TBD"
    ],
    "Regular Season MVP": [
        "Shaquille O'Neal", "Allen Iverson", "Tim Duncan", "Tim Duncan", "Kevin Garnett",
        "Steve Nash", "Steve Nash", "Dirk Nowitzki", "Kobe Bryant", "LeBron James",
        "Derrick Rose", "LeBron James", "LeBron James", "Kevin Durant", "Stephen Curry",
        "Stephen Curry", "Russell Westbrook", "James Harden", "Giannis Antetokounmpo", "Giannis Antetokounmpo",
        "Nikola Jokić", "Nikola Jokić", "Nikola Jokić", "Joel Embiid", "Nikola Jokić", "TBD"
    ],
    "Regular Season MVP Stats (PPG, APG, RPG)": [
        "28.7 ppg, 3.7 apg, 13.6 rpg", "31.1 ppg, 4.6 apg, 3.8 rpg", "23.3 ppg, 3.9 apg, 12.9 rpg",
        "22.3 ppg, 3.1 apg, 12.4 rpg", "24.2 ppg, 5.0 apg, 13.9 rpg", "15.5 ppg, 11.5 apg, 3.3 rpg",
        "18.8 ppg, 10.5 apg, 4.2 rpg", "24.6 ppg, 3.4 apg, 8.9 rpg", "28.3 ppg, 4.4 apg, 6.3 rpg",
        "29.7 ppg, 7.3 apg, 8.6 rpg", "25.0 ppg, 7.7 apg, 4.1 rpg", "26.8 ppg, 8.0 apg, 7.3 rpg",
        "27.1 ppg, 6.2 apg, 7.9 rpg", "32.0 ppg, 5.5 apg, 7.4 rpg", "23.8 ppg, 7.7 apg, 4.3 rpg",
        "30.1 ppg, 6.7 apg, 5.4 rpg", "31.6 ppg, 10.4 apg, 10.7 rpg", "30.4 ppg, 8.8 apg, 5.4 rpg",
        "27.7 ppg, 5.9 apg, 12.5 rpg", "29.5 ppg, 5.6 apg, 13.6 rpg", "27.1 ppg, 7.9 apg, 13.8 rpg",
        "27.2 ppg, 7.9 apg, 13.8 rpg", "24.5 ppg, 11.8 apg, 11.8 rpg", "30.3 ppg, 4.9 apg, 11.7 rpg",
        "26.4 ppg, 8.3 apg, 12.2 rpg", "TBD"
    ]
}

# Simulated Runner-Up Data (Top 5 for each year, partial real data)
runner_up_data = {
    "Year": list(range(2000, 2026)),
    "MVP Runner-Ups": [
        ["Kevin Garnett", "Alonzo Mourning", "Karl Malone", "Tim Duncan", "Gary Payton"],
        ["Shaquille O'Neal", "Tim Duncan", "Kevin Garnett", "Chris Webber", "Tracy McGrady"],
        ["Kevin Garnett", "Shaquille O'Neal", "Tracy McGrady", "Kobe Bryant", "Allen Iverson"],
        ["Kevin Garnett", "Shaquille O'Neal", "Kobe Bryant", "Jason Kidd", "Tracy McGrady"],
        ["Tim Duncan", "Steve Nash", "Shaquille O'Neal", "Kobe Bryant", "Allen Iverson"],
        ["Dirk Nowitzki", "Kobe Bryant", "Shaquille O'Neal", "LeBron James", "Tim Duncan"],
        ["Dirk Nowitzki", "Kobe Bryant", "LeBron James", "Shaquille O'Neal", "Dwyane Wade"],
        ["Kobe Bryant", "LeBron James", "Dwyane Wade", "Chris Paul", "Tim Duncan"],
        ["LeBron James", "Chris Paul", "Kevin Garnett", "Dwight Howard", "Deron Williams"],
        ["Dwyane Wade", "Kobe Bryant", "Chris Paul", "Dwight Howard", "Kevin Durant"],
        ["LeBron James", "Kevin Durant", "Kobe Bryant", "Dwyane Wade", "Russell Westbrook"],
        ["Kevin Durant", "Derrick Rose", "Kobe Bryant", "Chris Paul", "Dwyane Wade"],
        ["Kevin Durant", "Chris Paul", "Kobe Bryant", "Tony Parker", "Carmelo Anthony"],
        ["LeBron James", "Chris Paul", "James Harden", "Kobe Bryant", "Russell Westbrook"],
        ["James Harden", "Kevin Durant", "LeBron James", "Russell Westbrook", "Stephen Curry"],
        ["James Harden", "Russell Westbrook", "Kevin Durant", "LeBron James", "Kawhi Leonard"],
        ["James Harden", "LeBron James", "Stephen Curry", "Kevin Durant", "Anthony Davis"],
        ["Giannis Antetokounmpo", "LeBron James", "Kevin Durant", "Stephen Curry", "Kawhi Leonard"],
        ["James Harden", "Paul George", "Nikola Jokić", "Stephen Curry", "Damian Lillard"],
        ["LeBron James", "James Harden", "Anthony Davis", "Damian Lillard", "Luka Dončić"],
        ["Joel Embiid", "Giannis Antetokounmpo", "Luka Dončić", "James Harden", "Stephen Curry"],
        ["Joel Embiid", "Giannis Antetokounmpo", "Jayson Tatum", "Luka Dončić", "Kevin Durant"],
        ["Joel Embiid", "Luka Dončić", "Giannis Antetokounmpo", "Jayson Tatum", "Shai Gilgeous-Alexander"],
        ["Nikola Jokić", "Luka Dončić", "Jayson Tatum", "Giannis Antetokounmpo", "Shai Gilgeous-Alexander"],
        ["Shai Gilgeous-Alexander", "Luka Dončić", "Jayson Tatum", "Giannis Antetokounmpo", "Anthony Davis"],
        ["TBD", "TBD", "TBD", "TBD", "TBD"]
    ]
}

# Create DataFrames
df = pd.DataFrame(data)
runner_up_df = pd.DataFrame(runner_up_data)

# Create dropdown widget
year_dropdown = widgets.Dropdown(
    options=[str(year) for year in range(2000, 2026)],
    value=None,  # No default selection
    description='Select Year:',
    disabled=False,
    style={'description_width': 'initial'}
)

# Output widget
output = widgets.Output()

# Function to display both tables
def on_year_change(change):
    with output:
        clear_output(wait=True)  # Clear previous output
        selected_year = change['new']
        if selected_year is not None:  # Ensure a year is selected
            year = int(selected_year)
            result = df[df["Year"] == year].iloc[0]
            runner_up_result = runner_up_df[runner_up_df["Year"] == year].iloc[0]
            
            # Main stats table
            table_html = f"""
            <h3>NBA Stats for {year}</h3>
            <table style='border-collapse: collapse; width: 100%;'>
                <tr style='background-color: #f2f2f2;'>
                    <th style='border: 1px solid #ddd; padding: 8px;'>Category</th>
                    <th style='border: 1px solid #ddd; padding: 8px;'>Details</th>
                </tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>NBA Champion</td><td style='border: 1px solid #ddd; padding: 8px;'>{result['NBA Champion']}</td></tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>Beat in Series</td><td style='border: 1px solid #ddd; padding: 8px;'>{result['Beat in Series']}</td></tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>Finals MVP</td><td style='border: 1px solid #ddd; padding: 8px;'>{result['Finals MVP']}</td></tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>Finals MVP Stats</td><td style='border: 1px solid #ddd; padding: 8px;'>{result['Finals MVP Stats (PPG, APG, RPG)']}</td></tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>Regular Season MVP</td><td style='border: 1px solid #ddd; padding: 8px;'>{result['Regular Season MVP']}</td></tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>Regular Season MVP Stats</td><td style='border: 1px solid #ddd; padding: 8px;'>{result['Regular Season MVP Stats (PPG, APG, RPG)']}</td></tr>
            </table>
            """
            
            # Runner-up table
            runner_up_html = f"""
            <h3>MVP Voting Runner-Ups for {year}</h3>
            <table style='border-collapse: collapse; width: 100%; margin-top: 20px;'>
                <tr style='background-color: #f2f2f2;'>
                    <th style='border: 1px solid #ddd; padding: 8px;'>Rank</th>
                    <th style='border: 1px solid #ddd; padding: 8px;'>Player</th>
                </tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>2nd</td><td style='border: 1px solid #ddd; padding: 8px;'>{runner_up_result['MVP Runner-Ups'][0]}</td></tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>3rd</td><td style='border: 1px solid #ddd; padding: 8px;'>{runner_up_result['MVP Runner-Ups'][1]}</td></tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>4th</td><td style='border: 1px solid #ddd; padding: 8px;'>{runner_up_result['MVP Runner-Ups'][2]}</td></tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>5th</td><td style='border: 1px solid #ddd; padding: 8px;'>{runner_up_result['MVP Runner-Ups'][3]}</td></tr>
                <tr><td style='border: 1px solid #ddd; padding: 8px;'>6th</td><td style='border: 1px solid #ddd; padding: 8px;'>{runner_up_result['MVP Runner-Ups'][4]}</td></tr>
            </table>
            """
            
            display(HTML(table_html + runner_up_html))
        else:
            display(HTML("<p>Please select a year to view stats.</p>"))

# Bind the function to the dropdown
year_dropdown.observe(on_year_change, names='value')

# Display dropdown and output together
display(widgets.VBox([year_dropdown, output]))

# Initial output
with output:
    display(HTML("<p>Please select a year to view stats.</p>"))
